# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/raw/09007bd.csv",sep=";",encoding="latin1")

df
# Out:
#   Tipología penal\tPeriodos:\tComunidades autónomas\tTotal
# 0  III. TOTAL INFRACCIONES PENALES\tenero-septiem...

# %%
df.describe().T
# Out:
#                                                    count unique  \
# Tipología penal\tPeriodos:\tComunidades autónom...     1      1
#
#                                                                                                   top  \
# Tipología penal\tPeriodos:\tComunidades autónom...  III. TOTAL INFRACCIONES PENALES\tenero-septiem...
#
#                                                    freq
# Tipología penal\tPeriodos:\tComunidades autónom...    1
